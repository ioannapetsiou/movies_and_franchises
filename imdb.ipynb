# %% [markdown]
# ### In this notebook I will be using data from Imdb movies

# %%
#importing libraries
import pandas as pd
import numpy as np
import requests 
import matplotlib.pyplot as plt

#pd.set_option("display.max_rows", None)
#pd.set_option("display.max_columns", None)

# %%
#I have a file in my computer called "title.ratings.tsv.gz" and I am calling it as a dataframe
#this file is "tab seperated" and I am changing that so that it works as a csv
df = pd.read_csv("title.ratings.tsv.gz",
                 sep="\t",
                 encoding="latin-1",
                 na_values=[0])
df
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2058
# 1        tt0000002            5.6       277
# 2        tt0000003            6.5      2026
# 3        tt0000004            5.4       179
# 4        tt0000005            6.2      2793
# ...            ...            ...       ...
# 1450426  tt9916730            7.0        12
# 1450427  tt9916766            7.1        23
# 1450428  tt9916778            7.2        37
# 1450429  tt9916840            7.2        10
# 1450430  tt9916880            8.6         8
#
# [1450431 rows x 3 columns]

# %%
#same as the cell above - I am calling a dataset and displaying it
df2 = pd.read_csv("title.basics.tsv.gz",
                 sep="\t",
                 encoding="latin-1",
                 na_values=[0])
df2
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18640\427017250.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("title.basics.tsv.gz",
#              tconst  titleType               primaryTitle  \
# 0         tt0000001      short                 Carmencita
# 1         tt0000002      short     Le clown et ses chiens
# 2         tt0000003      short             Pauvre Pierrot
# 3         tt0000004      short                Un bon bock
# 4         tt0000005      short           Blacksmith Scene
# ...             ...        ...                        ...
# 10886127  tt9916848  tvEpisode              Episode #3.17
# 10886128  tt9916850  tvEpisode              Episode #3.19
# 10886129  tt9916852  tvEpisode              Episode #3.20
# 10886130  tt9916856      short                   The Wind
# 10886131  tt9916880  tvEpisode  Horrid Henry Knows It All
#
# ...

# %%
#only keeping the rows were the titleType is a movie, and displaying the changed dataset
df2 = df2[df2['titleType'].str.lower() == "movie"]
df2
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 498       tt0000502     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# ...             ...       ...
# 10886023  tt9916622     movie
# 10886050  tt9916680     movie
# 10886062  tt9916706     movie
# 10886072  tt9916730     movie
# 10886082  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 498                                                Bohemios
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# ...                                                     ...
# 10886023       Rodolpho TeÃ³philo - O Legado de um Pioneiro
# 10886050  De la ilusiÃ³n al desconcierto: cine colombian...
# ...

# %%
#merging the 2 datasets from before into one on the "tconst" column, that seems to be like a code for each movie
merged_df = pd.merge(df, df2, on='tconst', how='inner')
merged_df
# Out:
#            tconst  averageRating  numVotes titleType  \
# 0       tt0000009            5.4       211     movie
# 1       tt0000147            5.2       517     movie
# 2       tt0000502            4.4        17     movie
# 3       tt0000574            6.0       911     movie
# 4       tt0000591            5.6        26     movie
# ...           ...            ...       ...       ...
# 312279  tt9916362            6.4      5839     movie
# 312280  tt9916428            3.6        19     movie
# 312281  tt9916538            8.3         9     movie
# 312282  tt9916706            7.6         5     movie
# 312283  tt9916730            7.0        12     movie
#
#                          primaryTitle                  originalTitle isAdult  \
# 0                          Miss Jerry                     Miss Jerry     NaN
# 1       The Corbett-Fitzsimmons Fight  The Corbett-Fitzsimmons Fight     NaN
# 2                            Bohemios                       Bohemios     NaN
# ...

# %%
#sorting the new merged dataframe by the number of Votes so that i only get popular movies. Then i reset the index
merged_df = merged_df.sort_values(by='numVotes', ascending=False).reset_index(drop=True)
merged_df
# Out:
#             tconst  averageRating  numVotes titleType  \
# 0        tt0111161            9.3   2908911     movie
# 1        tt0468569            9.0   2890098     movie
# 2        tt1375666            8.8   2567778     movie
# 3        tt0137523            8.8   2342094     movie
# 4        tt0109830            8.8   2274178     movie
# ...            ...            ...       ...       ...
# 312279   tt7856410            7.6         5     movie
# 312280   tt0233560            6.8         5     movie
# 312281   tt6722888            7.2         5     movie
# 312282   tt6723148            9.0         5     movie
# 312283  tt21027842            5.8         5     movie
#
#                                              primaryTitle  \
# 0                                The Shawshank Redemption
# 1                                         The Dark Knight
# 2                                               Inception
# 3                                              Fight Club
# ...

# %%
#I only want to keep the first 500 rows of the sorted dataframe
merged_df = merged_df.iloc[:500]
merged_df
# Out:
#         tconst  averageRating  numVotes titleType              primaryTitle  \
# 0    tt0111161            9.3   2908911     movie  The Shawshank Redemption
# 1    tt0468569            9.0   2890098     movie           The Dark Knight
# 2    tt1375666            8.8   2567778     movie                 Inception
# 3    tt0137523            8.8   2342094     movie                Fight Club
# 4    tt0109830            8.8   2274178     movie              Forrest Gump
# ..         ...            ...       ...       ...                       ...
# 495  tt0478311            6.9    386014     movie                Knocked Up
# 496  tt0338751            7.5    385666     movie               The Aviator
# 497  tt0388795            7.7    385604     movie        Brokeback Mountain
# 498  tt0162661            7.3    385540     movie             Sleepy Hollow
# 499  tt0343660            6.8    384812     movie            50 First Dates
#
# ...

# %%
#I only want to keep specific columns, so once again I resave my dataframe with what I want to keep
merged_df = merged_df[['averageRating','numVotes','originalTitle','startYear', 'genres']]
merged_df
# Out:
#      averageRating  numVotes             originalTitle startYear  \
# 0              9.3   2908911  The Shawshank Redemption      1994
# 1              9.0   2890098           The Dark Knight      2008
# 2              8.8   2567778                 Inception      2010
# 3              8.8   2342094                Fight Club      1999
# 4              8.8   2274178              Forrest Gump      1994
# ..             ...       ...                       ...       ...
# 495            6.9    386014                Knocked Up      2007
# 496            7.5    385666               The Aviator      2004
# 497            7.7    385604        Brokeback Mountain      2005
# 498            7.3    385540             Sleepy Hollow      1999
# 499            6.8    384812            50 First Dates      2004
#
#                       genres
# 0                      Drama
# 1         Action,Crime,Drama
# 2    Action,Adventure,Sci-Fi
# 3                      Drama
# 4              Drama,Romance
# ...

# %%
#now I want to see all rows of the datasets
#pd.set_option("display.max_rows", None)

# %%
#I have commented out the "see all rows" command, but I called my dataframe again to see all rows
#merged_df

# %%
#now I sort my dataframe again by the ratings of each movie
merged_df = merged_df.sort_values(by='averageRating', ascending=False).reset_index(drop=True)
merged_df
# Out:
#      averageRating  numVotes                        originalTitle startYear  \
# 0              9.3   2908911             The Shawshank Redemption      1994
# 1              9.2   2027049                        The Godfather      1972
# 2              9.0    872287                         12 Angry Men      1957
# 3              9.0   1372606                The Godfather Part II      1974
# 4              9.0   1460481                     Schindler's List      1993
# ..             ...       ...                                  ...       ...
# 495            6.1    480315                       Justice League      2017
# 496            6.0    430434  Transformers: Revenge of the Fallen      2009
# 497            5.9    724740                        Suicide Squad      2016
# 498            5.8    399603                                 2012      2009
# 499            5.3    489886                             Twilight      2008
#
#                        genres
# ...

# %%
#I rename the title and year column to match a dataset I will be using in an other motebook
merged_df = merged_df.rename(columns={"originalTitle": "Film", "startYear": "date"})

# %%
#I save it as a csv
#merged_df.to_csv("imdb.csv")

# %%
#I save it as a excel
#merged_df.to_excel("imdb.xlsx")
